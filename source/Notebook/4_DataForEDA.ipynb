# %% [markdown]
# Sau khi dùng Spotify API và xử lý dữ liệu, nhóm đã thu thập được 688431 dòng dữ liệu. Tuy nhiên nhóm vẫn muốn thu thập thêm một vài trường dữ liệu hữu ích cho việc phân tích dữ liệu. Do đó nhóm sử dụng thêm 2 API là Genius API và Rapid API để thu thập một số trường dữ liệu hữu ích như lyrics, ...

# %% [markdown]
# #### Chọn ra 10000 bài hát tiêu biểu

# %% [markdown]
# Vì data gốc thu thập được là 689400 dòng, tuy nhiên Rapid API chỉ giới hạn mỗi lần dùng là 100 bài hát. Do đó nhóm quyết định chọn ra 10.000 bài ngẫu nhiên nhưng phân bố đều ở 10 khoảng điểm popularity (từ 0 tới 100) để phân tích dữ liệu

# %%
import pandas as pd

# %%
df = pd.read_csv('../data/processed_data.csv')

# %%
df.head()
# Out:
#                      track_name    artist_name                    album_name  \
# 0                       seasons  wave to earth             summer flows 0.02
# 1                     Nahuhulog    Jed Baruelo                     Nahuhulog
# 2                        Ligaya           mrld                        Ligaya
# 3              Oceans & Engines           NIKI                        Nicole
# 4  Let You Break My Heart Again         Laufey  Let You Break My Heart Again
#
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.372   0.273    7   -10.629     1       0.0268         0.782
# 1         0.612   0.389    4   -12.725     0       0.0578         0.837
# 2         0.458   0.533    0    -5.249     1       0.0381         0.447
# 3         0.371   0.314    1    -8.920     1       0.0347         0.622
# 4         0.299   0.142    2   -15.134     1       0.0369         0.965
#
#    instrumentalness  liveness  valence    tempo  duration_ms  time_signature  \
# 0          0.046300    0.2190    0.165   60.038       255998               4
# 1          0.004610    0.3060    0.348  125.091       227262               4
# 2          0.000000    0.1140    0.343  149.832       248800               4
# 3          0.000012    0.0893    0.066   95.109       336000               4
# 4          0.113000    0.1110    0.123   76.748       269066               4
#
#    popularity release_date
# 0          79   2020-08-04
# 1          64   2022-05-13
# 2          65   2021-10-06
# 3          72   2022-08-11
# 4          76   2021-08-13
